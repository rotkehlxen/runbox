# %%
import garminconnect
import os
from getpass import getpass

# %%
email = input("Enter email address: ")
password = getpass("Enter password: ")

# %%
garmin = garminconnect.Garmin(email, password)

# %%
garmin.login('~/.garminconnect')
# Out:
# Login strategy portal+cffi failed: Portal login returned 429. Cloudflare is blocking this request.
# Login strategy portal+requests failed: Portal login returned 429. Cloudflare is blocking this request.
# Login strategy mobile+cffi failed: HTTP Error 429:
# Login strategy mobile+requests failed: Login failed (429 Rate Limit). Try again later.
# ---------------------------------------------------------------------------
# GarminConnectTooManyRequestsError         Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/runbox-eyupDPEu-py3.12/lib/python3.12/site-packages/garminconnect/__init__.py:476, in Garmin.login(self, tokenstore)
#     475     self.client._tokenstore_path = tokenstore_path
# --> 476 mfa_status, _legacy_token = self.client.login(
#     477     self.username,
#     478     self.password,
#     479     prompt_mfa=self.prompt_mfa,
#     480 )
#     481 # Persist tokens so next run restores without re-login/MFA
#
# File ~/Library/Caches/pypoetry/virtualenvs/runbox-eyupDPEu-py3.12/lib/python3.12/site-packages/garminconnect/client.py:215, in Client.login(self, email, password, prompt_mfa, return_on_mfa)
#     214 if isinstance(last_err, GarminConnectTooManyRequestsError):
# --> 215     raise last_err
#     216 raise GarminConnectConnectionError(
#     217     f"All login strategies failed. Last error: {last_err}"
#     218 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/runbox-eyupDPEu-py3.12/lib/python3.12/site-packages/garminconnect/client.py:191, in Client.login(self, email, password, prompt_mfa, return_on_mfa)
#     190     _LOGGER.debug("Trying login strategy: %s", name)
# --> 191     return method(
#     192         email,
#     193         password,
#     194         prompt_mfa=prompt_mfa,
#     195         return_on_mfa=return_on_mfa,
#     196     )
#     197 except GarminConnectAuthenticationError:  # noqa: PERF203
#     198     # Wrong credentials / invalid MFA — no point trying other strategies
#
# File ~/Library/Caches/pypoetry/virtualenvs/runbox-eyupDPEu-py3.12/lib/python3.12/site-packages/garminconnect/client.py:622, in Client._mobile_login(self, email, password, prompt_mfa, return_on_mfa)
#     621 if r.status_code == 429:
# --> 622     raise GarminConnectTooManyRequestsError(
#     623         "Login failed (429 Rate Limit). Try again later."
#     624     )
#     626 try:
#
# GarminConnectTooManyRequestsError: Login failed (429 Rate Limit). Try again later.
#
# The above exception was the direct cause of the following exception:
#
# GarminConnectAuthenticationError          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 garmin.login('~/.garminconnect')
#
# File ~/Library/Caches/pypoetry/virtualenvs/runbox-eyupDPEu-py3.12/lib/python3.12/site-packages/garminconnect/__init__.py:573, in Garmin.login(self, tokenstore)
#     571 auth_indicators = ["401", "unauthorized", "authentication", "login failed"]
#     572 if any(indicator in error_str for indicator in auth_indicators):
# --> 573     raise GarminConnectAuthenticationError(
#     574         f"Authentication failed: {e}"
#     575     ) from e
#     576 logger.exception("Login failed")
#     577 raise GarminConnectConnectionError(f"Login failed: {e}") from e
#
# GarminConnectAuthenticationError: Authentication failed: Login failed (429 Rate Limit). Try again later.

# %%
# old
garmin.login()

GARTH_HOME = os.getenv("GARTH_HOME", "~/.garth")
garmin.garth.dump(GARTH_HOME)
